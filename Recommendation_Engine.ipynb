# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7762f98-0acc-4267-8a0d-fe5161d09183" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7762f98-0acc-4267-8a0d-fe5161d09183">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import joblib

model = joblib.load("credit_risk_model_lgbm.pkl")

# %%
input_data = pd.DataFrame({
"loan_amount":[250000],
"income":[50000],
"Credit_Score":[650],
"LTV":[70],
"dtir1":[30]
})

# %%
def expected_loss_engine(input_data, raw_loan_amount):

    # Step 1: Predict default probability
    prob = model.predict_proba(input_data)[0][1]

    # Step 2: Use real loan amount
    loan_amount = raw_loan_amount

    # Step 3: Calculate expected loss
    expected_loss = prob * loan_amount

    # Step 4: Decision logic
    if expected_loss < 50000:
        decision = {
            "priority": "Low",
            "assigned_team": "Automated System",
            "recovery_channel": "Email + SMS Reminder",
            "follow_up_frequency": "Once in 15 days",
            "legal_action": False
        }

    elif expected_loss < 200000:
        decision = {
            "priority": "Medium",
            "assigned_team": "Call Center Agent",
            "recovery_channel": "Phone Call + EMI Restructure Offer",
            "follow_up_frequency": "Weekly",
            "legal_action": False
        }

    elif expected_loss < 500000:
        decision = {
            "priority": "High",
            "assigned_team": "Dedicated Recovery Officer",
            "recovery_channel": "Direct Call + Field Visit",
            "follow_up_frequency": "Every 5 days",
            "legal_action": False
        }

    else:
        decision = {
            "priority": "Critical",
            "assigned_team": "Senior Recovery & Legal Team",
            "recovery_channel": "Legal Notice + Field Investigation",
            "follow_up_frequency": "Every 3 days",
            "legal_action": True
        }

    return {
"default_probability": round(float(prob),4),
"expected_loss": round(float(expected_loss),2),
"decision_plan": decision
}

# %%
#result error
#solution:Your input data must contain all 36 features that the model was trained on.

#The easiest way is to use one row from your processed dataset.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c991e518-41c7-4446-8fbf-d03e0f946962" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c991e518-41c7-4446-8fbf-d03e0f946962">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("loan_data_processed.csv")

# %%
input_data = df.drop("Status", axis=1).iloc[[0]]

# %%
# Step 1: Select borrower input
input_data = df.drop("Status", axis=1).iloc[[0]]

# Step 2: Extract real loan amount
raw_loan_amount = df["loan_amount"].iloc[0]

# Step 3: Run recommendation engine
result = expected_loss_engine(input_data, raw_loan_amount)

print(result)
# Out:
# {'default_probability': 0.951, 'expected_loss': -1.11, 'decision_plan': {'priority': 'Low', 'assigned_team': 'Automated System', 'recovery_channel': 'Email + SMS Reminder', 'follow_up_frequency': 'Once in 15 days', 'legal_action': False}}
